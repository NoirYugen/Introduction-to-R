# %%
#Variable,   Simple Assignment Operator,          Value
Intro              =           "My name is Asha and these are some quotes from favorite authors that inspire me"


#Variable,   Leftward Assignment Operator,          Value
 Sylvia          <-            "Let me live, love, and say it well in good sentences."


#                    Value  ,                                                Rightward Assignment Operator,   Variable
"You will never be happy if you continue to search for what happiness consists of."    ->                     Albert

print(Intro)
print(Sylvia)
print(Albert)
# Out:
# [1] "My name is Asha and these are some quotes from favorite authors that inspire me"
# [1] "Let me live, love, and say it well in good sentences."
# [1] "You will never be happy if you continue to search for what happiness consists of."
